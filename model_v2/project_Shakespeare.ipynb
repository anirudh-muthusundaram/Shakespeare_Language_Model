# %%
import os
import requests
from bs4 import BeautifulSoup
import time

# Base URLs
GUTENBERG_BASE_URL = "https://www.gutenberg.org"
SHAKESPEARE_COLLECTION_URL = "https://www.gutenberg.org/ebooks/author/65"

# Directory to save the text files
OUTPUT_DIR = "shakespeare_works"

def fetch_page(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch {url}: {response.status_code}")
        return None
    return BeautifulSoup(response.text, "html.parser")

def clean_gutenberg_text(text):
    lines = text.splitlines()
    start_index = None
    end_index = None

    # Find start marker
    for i, line in enumerate(lines):
        if "*** START OF THIS PROJECT GUTENBERG EBOOK" in line.upper():
            start_index = i
            break

    # Find end marker
    for i, line in enumerate(lines):
        if "*** END OF THIS PROJECT GUTENBERG EBOOK" in line.upper():
            end_index = i
            break

    # If both markers found, extract only the text in between
    if start_index is not None and end_index is not None and end_index > start_index:
        # The actual text usually starts after the start marker line
        lines = lines[start_index+1:end_index]
    else:
        # If markers not found, text remains as is.
        pass

    cleaned_text = "\n".join(lines)
    return cleaned_text

def download_work(work_url, title):
    response = requests.get(work_url)
    if response.status_code != 200:
        print(f"Failed to download {work_url}: {response.status_code}")
        return

    raw_text = response.text
    cleaned_text = clean_gutenberg_text(raw_text)

    # Save the cleaned text
    filename = f"{OUTPUT_DIR}/{title}.txt"
    with open(filename, "w", encoding="utf-8") as file:
        file.write(cleaned_text)
    print(f"Saved: {filename}")

def main():
    # Ensure output directory exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    # Fetch Shakespeare's collection page
    soup = fetch_page(SHAKESPEARE_COLLECTION_URL)
    if not soup:
        print("Failed to load the Shakespeare collection page.")
        return

    # Find all book links on the page
    book_links = soup.select('li.booklink a[href]')
    if not book_links:
        print("No book links found.")
        return

    for link in book_links:
        book_title = link.get('title', 'Unknown Title').replace("/", "_")  # Handle special characters
        book_url = GUTENBERG_BASE_URL + link['href']
        print(f"Processing: {book_title} - {book_url}")

        # Navigate to the book's page to find the plain text download link
        book_soup = fetch_page(book_url)
        if not book_soup:
            continue

        # Look for plain text link (UTF-8 version preferred)
        plain_text_link = book_soup.find("a", string="Plain Text UTF-8")
        if not plain_text_link:
            print(f"No plain text link found for: {book_title}")
            continue

        plain_text_url = GUTENBERG_BASE_URL + plain_text_link['href']
        print(f"Downloading: {book_title} from {plain_text_url}")
        download_work(plain_text_url, book_title)

        # Delay to prevent overloading the server
        time.sleep(2)

if __name__ == "__main__":
    main()
# Out:
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1513
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1513.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/100
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/100.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/27761
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/27761.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1533
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1533.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/23042
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/23042.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1524
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1524.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1514
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1514.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1515
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1515.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1531
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1531.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1522
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1522.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1526
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1526.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1519
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1519.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1112
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1112.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1041
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1041.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1430
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1430.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1532
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1532.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1508
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1508.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/2245
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/2245.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1534
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1534.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1539
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1539.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/23045
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/23045.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/2265
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/2265.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/1523
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/1523.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/43440
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/43440.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt
# Processing: Unknown Title - https://www.gutenberg.org/ebooks/23046
# Downloading: Unknown Title from https://www.gutenberg.org/ebooks/23046.txt.utf-8
# Saved: shakespeare_works/Unknown Title.txt

# %%
import os

OUTPUT_DIR = "shakespeare_works"
combined_text_file = "combined_shakespeare.txt"

combined_text = ""
for filename in os.listdir(OUTPUT_DIR):
    with open(os.path.join(OUTPUT_DIR, filename), "r", encoding="utf-8") as file:
        combined_text += file.read().strip() + "\n\n"

with open(combined_text_file, "w", encoding="utf-8") as file:
    file.write(combined_text)
print(f"Combined texts saved to {combined_text_file}")
# Out:
# Combined texts saved to data_shakespeare.txt
